# %% [markdown]
# # Week 13 Programming Assignment
#
# As you're working on identifying data for your final project, it's helpful to spend some time exploring your various data files.  For this week's assignment, I'd like you to take a few of the ideas from the the lectures, review assignment, and tonight's lecture to start exploring the data you plan to use for the final project.
#
# For the following activities, you can use just one of the data files that you've identified, or you can do the activities using different data files.  That's up to you.  Please describe what you're doing in a Markdown cell or in the comments of your code.  When you've completed the assignment, submit it as normal.

# %% [markdown]
# ### 1. Basic Statistics
#
# Use Python to read in your data file and show many rows and columns your data has.

# %%
#Load COVID 19 vaccination data from healthdata.gov (https://healthdata.gov/dataset/COVID-19-Vaccinations-in-the-United-States-County/ipdn-uaih)

import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('/home/jupyter-msimkins7/hds5210-2022/COVID-19_Vaccinations_in_the_United_States_County_4.12.22.csv')

# %%
#get number of rows and columns
data.shape
# Out:
# (103768, 66)

# %% [markdown]
# ### 2. Data Diversity
#
# Use Python to identify how many unique values each column in your data has.  Use Python to identify which column has the greatest number of distinct values (aka the most diversity)?  If your data has a unique identifier (e.g. a person or visit or record ID) then find the column with the next most number of unique values.

# %%
data.columns

# %%
#get unique values for all columns in data frame:
for col in data.columns: 
    count = data[col].nunique()
    print('Count of Unique values in Column ', col, ' is : ', count)

unique_count= data.nunique()
# Out:
# Count of Unique values in Column  Date  is :  33
# Count of Unique values in Column  FIPS  is :  3225
# Count of Unique values in Column  MMWR_week  is :  5
# Count of Unique values in Column  Recip_County  is :  1960
# Count of Unique values in Column  Recip_State  is :  59
# Count of Unique values in Column  Completeness_pct  is :  60
# Count of Unique values in Column  Administered_Dose1_Recip  is :  48960
# Count of Unique values in Column  Administered_Dose1_Pop_Pct  is :  691
# Count of Unique values in Column  Administered_Dose1_Recip_5Plus  is :  49012
# Count of Unique values in Column  Administered_Dose1_Recip_5PlusPop_Pct  is :  673
# Count of Unique values in Column  Administered_Dose1_Recip_12Plus  is :  48482
# Count of Unique values in Column  Administered_Dose1_Recip_12PlusPop_Pct  is :  644
# Count of Unique values in Column  Administered_Dose1_Recip_18Plus  is :  47348
# Count of Unique values in Column  Administered_Dose1_Recip_18PlusPop_Pct  is :  625
# ...

# %%
#get max unique count
max_unique_count= max(unique_count)

# %%
max_unique_count
# Out:
# 49012

# %% [markdown]
# Max unique count is 49012, which means the column "Administered_Dose1_Recip_5Plus" has the most unique values out of all the variables in the dataframe

# %% [markdown]
# ### 3. Data Redundancy
#
# Use Python to identify any columns in your data where the value for every row is the same.  For example, if you had a gender column and all the rows said 'M', then you would want to write the code that helped you determine that.

# %%
#determine if there are any columns where every row is the same
print(data.duplicated())
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 103763    False
# 103764    False
# 103765    False
# 103766    False
# 103767    False
# Length: 103768, dtype: bool

# %%
a = data.values
b = (a ==a[:,[0]]).all(axis=1)
print(b)
# Out:
# [False False False ... False False False]

# %% [markdown]
# None of the columns have rows that are all the same values

# %% [markdown]
# ### 4. Range of Values
#
# Your data almost certainly has some numeric columns that can be summed or averaged.  Create a histogram that shows the distribution of values for this column.

# %%
#create histograms of all numerical values from data set; important to note that some of these won't be meaningful like the 
#distribution of the MMWR week
hist = data.hist(figsize=(50,25))

# %% [markdown]
# ### 5. Discussion
#
# Do any additional exploration of this data that you think may be interesting and include your code here.  Then go onto Slack and make a post about what you've observed.  Share your observation.  Share your code, if you like.  Share a screenshot of the data or a chart based on the data.
#
# Then comment on at least two other people's observations that they share on Slack.  (Use the reply as thread option in Slack to keep the conversation organized.)

# %%
#create dataframe with only most recent data to reflect up to date vax data
data_recent = data[(data.Date =="04/14/2022")]

# %%
#get histograms of percent of 65+ population with COVID booster vax by state 
data_recent['Booster_Doses_65Plus_Vax_Pct'].hist(by=data['Recip_State'],figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5d90b81ef0>,
# ...
#       dtype=object)

# %% [markdown]
# ---
#
#
#
# ## Submitting Your Work
#
# In order to submit your work, you'll need to use the `git` command line program to **add** your homework file (this file) to your local repository, **commit** your changes to your local repository, and then **push** those changes up to github.com.  From there, I'll be able to **pull** the changes down and do my grading.  I'll provide some feedback, **commit** and **push** my comments back to you.  Next week, I'll show you how to **pull** down my comments.
#
# To run through everything one last time and submit your work:
# 1. Use the `Kernel` -> `Restart Kernel and Run All Cells` menu option to run everything from top to bottom and stop here.
# 2. Follow the instruction on the prompt below to either ssave and submit your work, or continue working.
#
# If anything fails along the way with this submission part of the process, let me know.  I'll help you troubleshoort.

# %% [markdown]
# ---

# %%
a=input('''
Are you ready to submit your work?
1. Click the Save icon (or do Ctrl-S / Cmd-S)
2. Type "yes" or "no" below
3. Press Enter

''')

if a=='yes':
    # !git add week13_assignment_2.ipynb
    # !git commit -a -m "Submitting the week 12 programming assignment"
    # !git push
else:
    print('''
    
OK. We can wait.
''')
# Out:
# Are you ready to submit your work?
# 1. Click the Save icon (or do Ctrl-S / Cmd-S)
# 2. Type "yes" or "no" below
# 3. Press Enter
#
#  yes
# [main 84ad0e2] Submitting the week 12 programming assignment
#  2 files changed, 517 insertions(+), 7 deletions(-)
#  create mode 100644 week13/week13_assignment_2.ipynb
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 236.30 KiB | 8.75 MiB/s, done.
# Total 5 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To github.com:msimkins7/hds5210-2022.git
#    26c19a8..84ad0e2  main -> main
